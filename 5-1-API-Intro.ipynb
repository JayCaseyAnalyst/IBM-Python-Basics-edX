# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# # Application Programming Interface
#
#
# Estimated time needed: **15** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Create and Use APIs in Python

# %% [markdown]
# ### Introduction
#
# An API lets two pieces of software talk to each other. Just like a function,  you don’t have to know how the API works only its inputs and outputs.  An essential type of API is a REST API that allows you to access resources via the internet. In this lab, we will review the Pandas Library  in the context of an API, we will also review a basic REST API

# %% [markdown]
# ## Table of Contents
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <li><a href="#ref0">Pandas is an API</a></li>
# <li><a href="#ref1">REST APIs Basics  </a></li>
# <li><a href="#ref2">Quiz on Tuples</a></li>
#
# </div>
#
# <hr>

# %%
# !pip install pycoingecko
# !pip install plotly
# !pip install mplfinance
# !pip install --upgrade nbformat
# Out:
# Collecting pycoingecko
#   Downloading pycoingecko-3.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting requests (from pycoingecko)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->pycoingecko)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->pycoingecko)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->pycoingecko)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->pycoingecko)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading pycoingecko-3.1.0-py3-none-any.whl (8.8 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 1.6 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    --------------------------- ------------ 112.6/163.8 kB ? eta -:--:--
#    --------------------------- ------------ 112.6/163.8 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.8 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 153.6/163.8 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 153.6/163.8 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 153.6/163.8 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- 163.8/163.8 kB 518.7 kB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB 2.8 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 1.1 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, pycoingecko
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 pycoingecko-3.1.0 requests-2.31.0 urllib3-2.2.1
# Collecting plotly
#   Downloading plotly-5.19.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: packaging in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly) (23.2)
# Downloading plotly-5.19.0-py3-none-any.whl (15.7 MB)
#    ---------------------------------------- 0.0/15.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.7 MB 762.6 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/15.7 MB 726.2 kB/s eta 0:00:22
#    ---------------------------------------- 0.2/15.7 MB 980.4 kB/s eta 0:00:16
#    - -------------------------------------- 0.5/15.7 MB 1.8 MB/s eta 0:00:09
#    -- ------------------------------------- 1.0/15.7 MB 3.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.2/15.7 MB 6.0 MB/s eta 0:00:03
#    --------- ------------------------------ 3.6/15.7 MB 7.0 MB/s eta 0:00:02
#    -------------- ------------------------- 5.7/15.7 MB 8.1 MB/s eta 0:00:02
#    ------------------ --------------------- 7.4/15.7 MB 9.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.2/15.7 MB 11.3 MB/s eta 0:00:01
#    -------------------------- ------------- 10.5/15.7 MB 16.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.7 MB 17.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.9/15.7 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.7 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.7/15.7 MB 8.7 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.19.0 tenacity-8.2.3
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Collecting matplotlib (from mplfinance)
#   Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting pandas (from mplfinance)
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->mplfinance)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->mplfinance)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mplfinance)
#   Downloading fonttools-4.49.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/162.3 kB 1.1 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/162.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 162.3/162.3 kB 1.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->mplfinance)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mplfinance) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mplfinance) (23.2)
# Collecting pillow>=8 (from matplotlib->mplfinance)
#   Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->mplfinance)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->mplfinance)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->mplfinance)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------------------------------- 75.0/75.0 kB 1.4 MB/s eta 0:00:00
# Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/7.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/7.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/7.6 MB 3.2 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/7.6 MB 3.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/7.6 MB 3.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/7.6 MB 3.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/7.6 MB 3.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/7.6 MB 2.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/7.6 MB 3.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.5/7.6 MB 3.4 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.6 MB 4.5 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.6 MB 4.5 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.6 MB 4.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.0/7.6 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.4/7.6 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 6.0/7.6 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 7.2 MB/s eta 0:00:00
# Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.6 MB 29.4 MB/s eta 0:00:01
#    ------------- -------------------------- 4.0/11.6 MB 31.8 MB/s eta 0:00:01
#    ------------------ --------------------- 5.4/11.6 MB 31.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.1/11.6 MB 30.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.6/11.6 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 8.0 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.6 kB ? eta -:--:--
#    ---------------------------------------- 187.6/187.6 kB 3.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.49.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------------ --------------- 1.3/2.2 MB 42.0 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 34.5 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 34.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 15.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 976.1 kB/s eta 0:00:00
# Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------------------------------------- -- 2.5/2.6 MB 53.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 42.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 18.7 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------  102.4/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB 1.5 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------  501.8/505.5 kB 32.8 MB/s eta 0:00:01
#    --------------------------------------- 505.5/505.5 kB 10.5 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 22.3 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, pandas, matplotlib, mplfinance
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 mplfinance-0.12.10b0 pandas-2.2.1 pillow-10.2.0 pyparsing-3.1.1 pytz-2024.1 tzdata-2024.1
# Collecting nbformat
#   Downloading nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastjsonschema (from nbformat)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: jupyter-core in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (5.7.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (5.14.1)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Downloading referencing-0.33.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Downloading rpds_py-0.18.0-cp311-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core->nbformat) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\jared\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core->nbformat) (306)
# Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/77.6 kB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 41.0/77.6 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 77.6/77.6 kB 617.9 kB/s eta 0:00:00
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.5 kB ? eta -:--:--
#    ---------------------------------------- 85.5/85.5 kB 2.4 MB/s eta 0:00:00
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.33.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp311-none-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.7 kB ? eta -:--:--
#    ----------------------- ---------------- 122.9/206.7 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  204.8/206.7 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 206.7/206.7 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: fastjsonschema, rpds-py, attrs, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed attrs-23.2.0 fastjsonschema-2.19.1 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 nbformat-5.9.2 referencing-0.33.0 rpds-py-0.18.0

# %% [markdown]
# <h2 id="PandasAPI">Pandas is an API </h2>

# %% [markdown]
# Pandas is actually set of software components , much of  which is not even written in Python.

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.offline import plot
import matplotlib.pyplot as plt
import datetime
from pycoingecko import CoinGeckoAPI
from mplfinance.original_flavor import candlestick2_ohlc

# %% [markdown]
# You create a dictionary, this is just data.

# %%
dict_={'a':[11,21,31],'b':[12,22,32]}

# %% [markdown]
# When you create a Pandas object with the Dataframe constructor in API lingo, this is an "instance". The data in the dictionary is passed along to the pandas API. You then use the dataframe to communicate with the API.

# %%
df=pd.DataFrame(dict_)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/pandas_api.png" width="800," align="center" alt="logistic regression block diagram">

# %% [markdown]
# When you call the method head the dataframe communicates with the API displaying the first few rows of the dataframe.

# %%
df.head()
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %% [markdown]
# When you call the method mean,the API will calculate the mean and return the value.

# %%
df.mean()
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %% [markdown]
# <h2 id="ref1">REST APIs</h2>

# %% [markdown]
# Rest API’s function by sending a request,  the request is communicated via HTTP message. The HTTP message usually contains a JSON file. This contains instructions for what operation we would like the service or resource to perform. In a similar manner, API returns a response, via an HTTP message, this response is usually contained within a JSON.
#
# In cryptocurrency a popular method to display the movements of the price of a currency.
#
# ![Example Candlestick Graph](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/candlestick.png)
#
# Here is a description of the candle sticks.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/explanation.png" alt="Candle Stick Definition" width="800" height="600">
#
# In this lab, we will be using the <a href=https://www.coingecko.com/en/api?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01>CoinGecko API</a> to create one of these candlestick graphs for Bitcoin. We will use the API to get the price data for 30 days with 24 observation per day, 1 per hour. We will find the max, min, open, and close price per day meaning we will have 30 candlesticks and use that to generate the candlestick graph. Although we are using the CoinGecko API we will use a Python client/wrapper for the API called <a href=https://github.com/man-c/pycoingecko>PyCoinGecko</a>. PyCoinGecko will make performing the requests easy and it will deal with the enpoint targeting.

# %% [markdown]
# Lets start off by getting the data we need. Using the <code>get_coin_market_chart_by_id(id, vs_currency, days)</code>. <code>id</code> is the name of the coin you want, <code>vs_currency</code> is the currency you want the price in, and <code>days</code> is how many days back from today you want.

# %%
cg = CoinGeckoAPI()

bitcoin_data = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=30)

# %%
type(bitcoin_data )
# Out:
# dict

# %% [markdown]
# The response we get is in the form of a JSON which includes the price, market caps, and total volumes along with timestamps for each observation. We are focused on the prices so we will select that data.

# %%
bitcoin_price_data = bitcoin_data['prices']

bitcoin_price_data[0:5]
# Out:
# [[1707001230546, 43014.05074546157],
#  [1707004824752, 42990.752025666065],
#  [1707008429910, 42998.086145217276],
#  [1707012030645, 43028.222156660224],
#  [1707015639833, 43000.79811280069]]

# %% [markdown]
# Finally lets turn this data into a Pandas DataFrame.

# %%
data = pd.DataFrame(bitcoin_price_data, columns=['TimeStamp', 'Price'])

# %% [markdown]
# Now that we have the DataFrame we will convert the timestamp to datetime and save it as a column called <code>Date</code>. We will map our <code>unix_to_datetime</code> to each timestamp and convert it to a readable datetime.

# %%
data['date'] = data['TimeStamp'].apply(lambda d: datetime.date.fromtimestamp(d/1000.0))

# %% [markdown]
# Using this modified dataset we can now group by the <code>Date</code> and find the min, max, open, and close for the candlesticks.

# %%
candlestick_data = data.groupby(data.date, as_index=False).agg({"Price": ['min', 'max', 'first', 'last']})
candlestick_data
# Out:
#           date         Price
#                          min           max         first          last
# 0   2024-02-03  42990.752026  43028.222157  43014.050745  43002.926172
# 1   2024-02-04  42317.548154  43047.660068  42887.153305  42706.304411
# 2   2024-02-05  42338.039409  43385.038414  42707.773130  42804.816840
# 3   2024-02-06  42690.289095  43234.629760  42767.552170  42758.555285
# 4   2024-02-07  42798.245423  44692.237425  42893.098639  44524.254317
# 5   2024-02-08  44452.112820  46324.980541  44467.400539  46079.026534
# 6   2024-02-09  45920.452965  47611.953475  45920.452965  47372.345136
# 7   2024-02-10  46909.823924  48487.284887  47416.466833  48487.284887
# 8   2024-02-11  48022.520845  48606.308450  48306.653867  48145.837436
# 9   2024-02-12  47882.163902  50162.575870  48074.007757  49783.437917
# 10  2024-02-13  48524.054937  50241.352178  49918.500051  49538.316873
# 11  2024-02-14  49396.573683  52414.812783  49396.573683  52375.183480
# 12  2024-02-15  51595.203506  52660.834749  52175.526693  52310.243792
# 13  2024-02-16  51738.283545  52356.797827  52162.693343  51988.317721
# 14  2024-02-17  50906.199496  52030.953104  52030.953104  51486.520575
# 15  2024-02-18  51518.351552  52199.821894  51583.194466  52080.840330
# 16  2024-02-19  51583.624317  52413.248102  52088.173698  51583.624317
# 17  2024-02-20  51281.192770  52814.460327  51783.283380  51997.460176
# 18  2024-02-21  50880.625422  51945.313901  51945.313901  51578.022414
# 19  2024-02-22  51067.967072  51965.033226  51467.555604  51067.967072
# 20  2024-02-23  50607.529201  51289.852015  51201.271638  50848.885475
# 21  2024-02-24  50950.327042  51697.485545  50950.327042  51621.629465
# 22  2024-02-25  51405.506495  51774.377397  51627.641280  51556.226972
# 23  2024-02-26  50926.780716  56318.200914  51549.897093  55580.073699
# 24  2024-02-27  55801.086600  57442.863211  55801.086600  56958.158311
# 25  2024-02-28  57116.640467  62518.580041  57227.461059  61594.439045
# 26  2024-02-29  60585.357601  62946.002884  62494.350476  61162.434616
# 27  2024-03-01  61269.633056  63136.302404  61488.640229  62360.176571
# 28  2024-03-02  61804.217372  62152.988986  62100.095784  61957.831015
# 29  2024-03-03  61642.541904  63782.626033  62050.496621  63441.246388
# 30  2024-03-04  63427.481105  67805.250223  63647.237430  67805.250223

# %% [markdown]
# Finally we are now ready to use plotly to create our Candlestick Chart.

# %%
fig = go.Figure(data=[go.Candlestick(x=candlestick_data['date'],
                open=candlestick_data['Price']['first'], 
                high=candlestick_data['Price']['max'],
                low=candlestick_data['Price']['min'], 
                close=candlestick_data['Price']['last'])
                ])

fig.update_layout(xaxis_rangeslider_visible=False)

fig.show()

# %% [markdown]
# ## Authors:
#
#
# ## Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-11-23 | 3.0 | Azim Hirjani | New API |
# | 2020-09-09 | 2.1 | Malika Singla | Spell Check |
# | 2020-08-26  | 2.0  | Lavanya | Moved lab to course repo in GitLab |
# |   |   |   |   |
#
#
#
#
# <hr/>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
